# %% [markdown]
# <a href="https://colab.research.google.com/github/luccouv/bigdata-boston-crimes/blob/master/map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap
from IPython.display import HTML, display

# ALL CRIMES IN BOSTON 2017
crime_df = pd.read_csv("./short2.csv", encoding="latin-1")
crime_df = crime_df.drop(columns='SHOOTING')
crime_df = crime_df.dropna(axis=0)
print(crime_df.isnull().sum(), "\nShape:", crime_df.shape)

map_hooray = folium.Map(location=[42.361145, -71.057083],
                        zoom_start=12, min_zoom=12)
#heat_df = crime_df[crime_df['YEAR'] == 2017]  # I take 2017 cause there is more crime against to other years
#heat_df = heat_df[heat_df['OFFENSE_CODE_GROUP'] == 'Larceny']
heat_df = heat_df[['Lat', 'Long']]  # giving only latitude and longitude now in heat_df just latitude and longitude

heat_data = [[row['Lat'], row['Long']] for index, row in heat_df.iterrows()]
# We have to give latitude and longitude like this [[lat, lon],[lat, lon],[lat, lon],[lat, lon],[lat, lon]]

HeatMap(heat_data, radius=10).add_to(map_hooray) # Adding map_hooray to HeatMap
map_hooray
# Out:
# Unnamed: 0             0
# INCIDENT_NUMBER        0
# OFFENSE_CODE           0
# OFFENSE_CODE_GROUP     0
# OFFENSE_DESCRIPTION    0
# DISTRICT               0
# REPORTING_AREA         0
# OCCURRED_ON_DATE       0
# YEAR                   0
# MONTH                  0
# DAY_OF_WEEK            0
# HOUR                   0
# UCR_PART               0
# STREET                 0
# Lat                    0
# Long                   0
# Location               0
# dtype: int64
# Shape: (18612, 17)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# CAR ACCIDENTS 2017
map_hooray2 = folium.Map(location=[42.361145, -71.057083],
                        zoom_start=12, min_zoom=12)
heat_df2 = crime_df[crime_df['YEAR'] == 2017]  # I take 2017 cause there is more crime against to other years
heat_df2 = heat_df2[heat_df2['OFFENSE_CODE_GROUP'] == 'Motor Vehicle Accident Response']
heat_df2 = heat_df2[['Lat', 'Long']]  # giving only latitude and longitude now in heat_df just latitude and longitude
# from 2017 larceny responde

boston = tuple([42.356145, -71.064083])
folium.CircleMarker(boston,
                    radius=50,
                    popup='Homicide',
                    color='red',
                    ).add_to(map_hooray2)


heat_data2 = [[row['Lat'], row['Long']] for index, row in heat_df2.iterrows()]
# We have to give latitude and longitude like this [[lat, lon],[lat, lon],[lat, lon],[lat, lon],[lat, lon]]

HeatMap(heat_data2, radius=10).add_to(map_hooray2) # Adding map_hooray to HeatMap
map_hooray2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# CAR ACCIDENTS 2018

map_hooray2 = folium.Map(location=[42.361145, -71.057083],
                        zoom_start=12, min_zoom=12)
heat_df2 = crime_df[crime_df['YEAR'] == 2018]  # I take 2017 cause there is more crime against to other years
heat_df2 = heat_df2[heat_df2['OFFENSE_CODE_GROUP'] == 'Motor Vehicle Accident Response']
heat_df2 = heat_df2[['Lat', 'Long']]  # giving only latitude and longitude now in heat_df just latitude and longitude
# from 2017 larceny responde

boston = tuple([42.356145, -71.064083])
folium.CircleMarker(boston,
                    radius=50,
                    popup='Homicide',
                    color='red',
                    ).add_to(map_hooray2)


heat_data2 = [[row['Lat'], row['Long']] for index, row in heat_df2.iterrows()]
# We have to give latitude and longitude like this [[lat, lon],[lat, lon],[lat, lon],[lat, lon],[lat, lon]]

HeatMap(heat_data2, radius=10).add_to(map_hooray2) # Adding map_hooray to HeatMap
map_hooray2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
